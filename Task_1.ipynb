# %% [markdown]
# #### Color Detection

# %% [markdown]
#  How many times has it occurred to you that even after seeing, you
# don't remember the name of the color? There can be 16 million colors based
# on the different RGB color values but we only remember a few. So in this project, we are going to build an interactive app that will detect the selected color from any image. To implement this we will need a labeled data of all the known colors then we will calculate which color resembles the most with the selected color value.

# %%
import numpy as np
import pandas as pd
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/colab'
# Out:
#  Ads_CTR_Optimisation.csv		 Mall_Customers.csv
#  amz_com-ecommerce_sample.csv		 marks.xlsx
#  brain_tumor_dataset			 movies.csv
#  color.jpg				 movies_metadata.csv
#  colorpic.jpg				 netflix_titles.csv
#  colors.csv				 online_retail_II.xlsx
#  country_wise_latest.csv		 russia_losses_equipment.csv
#  covid_19_clean_complete.csv		 russia_losses_personnel.csv
#  covid_19_india.csv			 Social_Network_Ads.csv
#  covid_vaccine_statewise.csv		 StatewiseTestingDetails.csv
#  credits.csv				'Student Mental health.csv'
#  Data.csv				 submission.csv
#  day_wise.csv				 submission.zip
# 'DS - Assignment Part 1 data set.xlsx'	 usa_county_wise.csv
#  flipkart_com-ecommerce_sample.csv	'voterfile .csv'
#  full_grouped.csv			 worldometer_data.csv

# %%
img = cv2.imread('/content/drive/MyDrive/colab/color.jpg')

# %%
csv = pd.read_csv('/content/drive/MyDrive/colab/colors.csv')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x188 at 0x7FC56AC6B580>

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 254]
#   [255 255 254]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 254 255]
#   [255 254 255]]
#
#  [[255 255 254]
#   [255 255 254]
#   [255 255 255]
#   ...
#   [253 255 255]
#   [255 254 255]
#   [255 254 255]]
#
#  [[255 255 254]
#   [255 255 254]
#   [255 255 255]
#   ...
#   [253 255 255]
#   [255 254 255]
#   [255 254 255]]]

# %%
index=["color","color_name","hex","R","G","B"]
csv = pd.read_csv('/content/drive/MyDrive/colab/colors.csv', names=index, header=None)

# %%
def getColorName(R,G,B):
    minimum = 1000
    for i in range(len(csv)):
        d = abs(R- int(csv.loc[i,"R"])) + abs(G- int(csv.loc[i,"G"]))+ abs(B- int(csv.loc[i,"B"]))
        if(d<minimum):
            minimum = d
            color_name = csv.loc[i,"color_name"]
    return color_name

# %%
clicked = False
r = g = b = xpos = ypos = 0

# %%
def draw_function(event, x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global b,g,r,xpos,ypos, clicked
        clicked = True
        xpos = x
        ypos = y
        b,g,r = img[y,x]
        b = int(b)
        g = int(g)
        r = int(r)

# %%
import numpy as np
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
color = np.uint8([[[b,g,r]]])
hsv_color = cv2.cvtColor(color,cv2.COLOR_BGR2HSV)
lower_range = np.array([10,100,20])
upper_range = np.array([25,255,255])

mask = cv2.inRange(hsv, lower_range, upper_range)

cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=350x188 at 0x7FC5A05F3370>

# %%
import numpy as np
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
color = np.uint8([[[b,g,r]]])
hsv_color = cv2.cvtColor(color,cv2.COLOR_BGR2HSV)
lower_range = np.array([0,100,20])
upper_range = np.array([10,255,255])

mask = cv2.inRange(hsv, lower_range, upper_range)

cv2_imshow(mask)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=350x188 at 0x7FC56A3A5F70>

# %%
import numpy as np
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
color = np.uint8([[[b,g,r]]])
hsv_color = cv2.cvtColor(color,cv2.COLOR_BGR2HSV)
lower_range = np.array([160,100,20])
upper_range = np.array([179,255,255])

mask = cv2.inRange(hsv, lower_range, upper_range)

cv2_imshow(mask)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=350x188 at 0x7FC56AC765B0>
